# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# Define the given parameters
E = 3.1
m = 0.1056583755
y = 29.3
theta = math.pi/10
b = math.sqrt(y**2 - 1)/y
theta_0 = 0.01
Em= m**2/(2*E*(1-b*math.cos(theta)))
E1= m**2/(2*E*(1-b*math.cos(theta+theta_0)))

E2=m**2/(2*E*(1-b*math.cos(theta-theta_0)))

def t(E_e):
    num = (E_e-E1)*E2-(E2-E_e)*E1
    den = E_e*(E2-E1)
    return math.acos(num/den)

#Check if values are working
print("The value of Em is:", Em)
print("The value of E1 is:", E1)
print("The value of E2 is:", E2)

# Define constants a and b1
a = 1-b*math.cos(theta)*math.cos(theta_0)
b1 = b*math.sin(theta)*math.sin(theta_0)

# Define functions for vortex
def v(E_e):
    if E_e >= E1 and E_e <= E2:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi) - 4*E*E_e*(a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)))
    elif E_e < E1:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a)-2*E*E_e*(2*a**2+b1**2))
    else:
        return None
def w(E_e):
    if E_e<=Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2))
    else:
         return None


# Define a range of values for E_e
E_e_values = [i/100000 for i in range(1, 4000)]

# Calculate the corresponding values of w and vortex for each E_e value
v_values = [v(E_e) for E_e in E_e_values]
w_values = [w(E_e) for E_e in E_e_values]

# Create a plot of w vs E_e and vortex vs E_e
fig, ax = plt.subplots()
ax.plot(E_e_values, v_values, color='red', label='Vortex')
ax.plot(E_e_values, w_values, color='black', label='PW')
ax.set_xlabel('$E_4$ (GeV)')
ax.set_ylabel('w(θ,$E_4$) (GeV$^{-1}$)')

plt.text(0, 1.5, r'$\theta_0 =$' + str(theta_0), fontsize=12)
# Add minor ticks to the x-axis
ax.minorticks_on()
ax.tick_params(which='minor', axis='y', color='k', width=0.5, length=0.5)
plt.legend()
plt.show()
# Out:
# The value of Em is: 0.03637746234670144
# The value of E1 is: 0.03421013121814065
# The value of E2 is: 0.038758522489138594

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# Define the given parameters
E = 3.1
m = 0.1056583755
y = 29.3
theta = math.pi/10
b = math.sqrt(y**2 - 1)/y
theta_0 = 0.1
Em= m**2/(2*E*(1-b*math.cos(theta)))
E1= m**2/(2*E*(1-b*math.cos(theta+theta_0)))

E2=m**2/(2*E*(1-b*math.cos(theta-theta_0)))

def t(E_e):
    num = (E_e-E1)*E2-(E2-E_e)*E1
    den = E_e*(E2-E1)
    return math.acos(num/den)

#Check if values are working
print("The value of Em is:", Em)
print("The value of E1 is:", E1)
print("The value of E2 is:", E2)

# Define constants a and b1
a = 1-b*math.cos(theta)*math.cos(theta_0)
b1 = b*math.sin(theta)*math.sin(theta_0)

# Define functions for vortex
def v(E_e):
    if E_e >= E1 and E_e <= E2:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi) - 4*E*E_e*(a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)))
    elif E_e < E1:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a)-2*E*E_e*(2*a**2+b1**2))
    else:
        return None
def w(E_e):
    if E_e<=Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2))
    else:
         return None


# Define a range of values for E_e
E_e_values = [i/100000 for i in range(1, 8000)]

# Calculate the corresponding values of w and vortex for each E_e value
v_values = [v(E_e) for E_e in E_e_values]
w_values = [w(E_e) for E_e in E_e_values]

# Create a plot of w vs E_e and vortex vs E_e
fig, ax = plt.subplots()
ax.plot(E_e_values, v_values, color='red', label='Vortex')
ax.plot(E_e_values, w_values, color='black', label='PW')
ax.set_xlabel('$E_4$ (GeV)')
ax.set_ylabel('$w(θ,E_4)$ (GeV$^{-1}$)')

plt.text(0, 1.5, r'$\theta_0 =$' + str(theta_0), fontsize=12)
# Add minor ticks to the x-axis
ax.minorticks_on()
ax.tick_params(which='minor', axis='y', color='k', width=0.5, length=0.5)
plt.legend()
plt.show()
# Out:
# The value of Em is: 0.03637746234670144
# The value of E1 is: 0.021163966187872283
# The value of E2 is: 0.07690297288056183

# %%
import math
import matplotlib.pyplot as plt

# Define the given parameters
E = 3.1
m = 0.1056583755
y = 29.3
theta = math.pi/20
b = math.sqrt(y**2 - 1)/y
theta_0 = 0.01
Em= m**2/(2*E*(1-b*math.cos(theta)))
E1= m**2/(2*E*(1-b*math.cos(theta+theta_0)))

E2=m**2/(2*E*(1-b*math.cos(theta-theta_0)))

def t(E_e):
    num = (E_e-E1)*E2-(E2-E_e)*E1
    den = E_e*(E2-E1)
    return math.acos(num/den)

#Check if values are working
print("The value of Em is:", Em)
print("The value of E1 is:", E1)
print("The value of E2 is:", E2)

# Define constants a and b1
a = 1-b*math.cos(theta)*math.cos(theta_0)
b1 = b*math.sin(theta)*math.sin(theta_0)

# Define functions for vortex
def v(E_e):
    if E_e >= E1 and E_e <= E2:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi) - 4*E*E_e*(a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)))
    elif E_e < E1:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a)-2*E*E_e*(2*a**2+b1**2))
    else:
        return None

def w(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2))
  else:
       return None

# Define a range of values for E_e
E_e_values = [i/10000 for i in range(1, 1600)]

# Calculate the corresponding values of w and vortex for each E_e value
v_values = [v(E_e) for E_e in E_e_values]
w_values = [w(E_e) for E_e in E_e_values]

# Create a plot of w vs E_e and vortex vs E_e
fig, ax = plt.subplots()
ax.plot(E_e_values, v_values, color='red', label='Vortex')
ax.plot(E_e_values, w_values, color='black', label='PW')
ax.set_xlabel('$E_4$ GeV')
ax.set_ylabel('w($\theta,E_4$) (GeV$^{-1}$)')

plt.text(0, 6, r'$\theta_0 =$' + str(theta_0), fontsize=12)
# Add minor ticks to the x-axis
ax.minorticks_on()
ax.tick_params(which='minor', axis='y', color='k', width=0.5, length=0.5)
plt.legend()
plt.show()
# Out:
# The value of Em is: 0.13972104691086845
# The value of E1 is: 0.12418039906039316
# The value of E2 is: 0.15832163702201893

# %%
import math
import matplotlib.pyplot as plt

# Define the given parameters
E = 3.1
m = 0.1056583755
y = 29.3
theta = math.pi/20
b = math.sqrt(y**2 - 1)/y
theta_0 = 0.1
Em= m**2/(2*E*(1-b*math.cos(theta)))
print("The value of Em is:", Em)
E1= m**2/(2*E*(1-b*math.cos(theta+theta_0)))

E2=m**2/(2*E*(1-b*math.cos(theta-theta_0)))

def t(E_e):
    num = (E_e-E1)*E2-(E2-E_e)*E1
    den = E_e*(E2-E1)
    return math.acos(num/den)

#Check if values are working
print("The value of E1 is:", E1)
print("The value of E2 is:", E2)

# Define constants a and b1
a = 1-b*math.cos(theta)*math.cos(theta_0)
b1 = b*math.sin(theta)*math.sin(theta_0)

# Define functions for vortex
def v(E_e):
    if E_e >= E1 and E_e <= E2:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi) - 4*E*E_e*(a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)))
    elif E_e < E1:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a)-2*E*E_e*(2*a**2+b1**2))
    else:
        return None

def w(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2))
  else:
       return None

# Define a range of values for E_e
E_e_values = [i/10000 for i in range(1, 8000)]

# Calculate the corresponding values of w and vortex for each E_e value
v_values = [v(E_e) for E_e in E_e_values]
w_values = [w(E_e) for E_e in E_e_values]

# Create a plot of w vs E_e and vortex vs E_e
fig, ax = plt.subplots()
ax.plot(E_e_values, v_values, color='red', label='Vortex')
ax.plot(E_e_values, w_values, color='black', label='PW')
ax.set_xlabel('$E_4$ GeV')
ax.set_ylabel('$w(\theta,E_4)$ (GeV$^{-1}$)')

plt.text(0.7, 6, r'$\theta_0 =$' + str(theta_0), fontsize=12)
# Add minor ticks to the x-axis
ax.minorticks_on()
ax.tick_params(which='minor', axis='y', color='k', width=0.5, length=0.5)
plt.legend()
plt.show()
# Out:
# The value of Em is: 0.13972104691086845
# The value of E1 is: 0.05386679749556684
# The value of E2 is: 0.8146610632876297

# %%
import math
import matplotlib.pyplot as plt
import numpy as np


# Define the given parameters
E = 3.1
m = 0.1056583755
y = E/m
theta = math.pi/60
b = math.sqrt(y**2 - 1)/y
theta_0 = 0.01
Em= m**2/(2*E*(1-b*math.cos(theta)))
print("The value of Em is:", Em)

E1= m**2/(2*E*(1-b*math.cos(theta+theta_0)))

E2=m**2/(2*E*(1-b*math.cos(theta-theta_0)))

# Define constants a and b1
a = 1-b*math.cos(theta)*math.cos(theta_0)
b1 = b*math.sin(theta)*math.sin(theta_0)

A_LE = a
B_LE = a**2 + (b1**2)/2
beta = b
gamma = y


def t(E_e):
    num = (E_e-E1)*E2-(E2-E_e)*E1
    den = E_e*(E2-E1)
    return math.acos(num/den)

def A_HE(E_e):
  return   (a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi)

def B_HE(E_e):
  return  a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)

#Check if values are working
print("The value of E1 is:", E1)
print("The value of E2 is:", E2)



# Define functions for vortex unpolarized
def vup(E_e):
    if E_e >= E1 and E_e <= E2:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi) - 4*E*E_e*(a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)))
    elif E_e < E1:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a)-2*E*E_e*(2*a**2+b1**2))
    else:
        return None


# Define functions for vortex parallel polarized
def VP(E_e):
    if E_e >= E1 and E_e <= E2:
        return (vup(E_e)+(4*y*(E_e**2)/(math.pi*m**5))*(m/E)*(((m**2*t(E_e)/np.pi - 4*E*E_e*A_HE(E_e))/(beta*y))-(y*(m**2*A_HE(E_e) - 4*E*E_e*B_HE(E_e))/beta)) )
    elif E_e < E1:
        return (vup(E_e)+(4*y*(E_e**2)/(math.pi*m**5))*(m/E)*(((m**2 - 4*E*E_e*A_LE)/(beta*y))-(y*(m**2*A_LE - 4*E*E_e*B_LE)/beta)))
    else:
        return None

# Define functions for vortex radial polarized
def RP(E_e):
    if E_e >= E1 and E_e <= E2:
        return  (vup(E_e)-(4*y*(E_e**2)/(math.pi*m**5))*(m/E)*((np.cos(theta_0)-beta*np.cos(theta))*(m**2*t(E_e)/math.pi-4*E*E_e*A_HE(E_e))/(beta*np.sin(theta_0))-np.cos(theta_0)*(m**2*A_HE(E_e)-4*E_e*E*B_HE(E_e))/(beta*np.sin(theta_0))))
    elif E_e < E1:
        return (vup(E_e)-(4*y*(E_e**2)/(math.pi*m**5))*(m/E)*((np.cos(theta_0)-beta*np.cos(theta))*(m**2-4*E*E_e*a)/(beta*np.sin(theta_0))-np.cos(theta_0)*(m**2*a-4*E_e*E*(a**2 + (b1**2)/2))/(beta*np.sin(theta_0))))
    else:
        return None


# Define functions for planewave unpolarized
def PWun(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2))
  else:
       return None

# Define functions for planewave forward-polarized
def PWP(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2-(beta-np.cos(theta))*(m**2-4*E*E_e*(1-b*math.cos(theta)))))
  else:
       return None

# Define a range of values for E_e
E_e_values = [i/10000 for i in range(1, 12000)]

# Calculate the corresponding values of w and vortex for each E_e value
vup_values = [vup(E_e) for E_e in E_e_values]
vp_values = [VP(E_e) for E_e in E_e_values]
pwun_values = [PWun(E_e) for E_e in E_e_values]
pwp_values = [PWP(E_e) for E_e in E_e_values]
rp_values = [RP(E_e) for E_e in E_e_values]
# Create a plot of w vs E_e and vortex vs E_e
fig, ax = plt.subplots()
ax.plot(E_e_values, vup_values, color='red', label='Vortex unpolarized')
ax.plot(E_e_values, vp_values, color='blue', label='Vortex parallel')
ax.plot(E_e_values, rp_values, color='green', label='Vortex radial')
ax.plot(E_e_values, pwun_values, color='black', label='PW unpoalrized')
ax.plot(E_e_values, pwp_values, color='yellow', label='PW polarized')
ax.set_xlabel('$E_4$ GeV')
ax.set_ylabel('$w(\theta,E_4)$ (GeV$^{-1}$)')

plt.text(0.7, 6, r'$\theta_0 =$' + str(theta_0), fontsize=12)
# Add minor ticks to the x-axis
ax.minorticks_on()
ax.tick_params(which='minor', axis='y', color='k', width=0.5, length=0.5)
plt.legend()
plt.show()
# Out:
# The value of Em is: 0.9230627799341063
# The value of E1 is: 0.713495999012278
# The value of E2 is: 1.2186521637663665

# %%
import math
import matplotlib.pyplot as plt
import numpy as np


# Define the given parameters
E = 3.1
m = 0.1056583755
y = 29.3
theta = math.pi/60
b = math.sqrt(y**2 - 1)/y
theta_0 = 0.01
Em= m**2/(2*E*(1-b*math.cos(theta)))
print("The value of Em is:", Em)

E1= m**2/(2*E*(1-b*math.cos(theta+theta_0)))

E2=m**2/(2*E*(1-b*math.cos(theta-theta_0)))

# Define constants a and b1
a = 1-b*math.cos(theta)*math.cos(theta_0)
b1 = b*math.sin(theta)*math.sin(theta_0)

A_LE = a
B_LE = a**2 + (b1**2)/2
beta = b
gamma = y


def t(E_e):
  if E_e >= E1 and E_e <= E2:
    num = (E_e-E1)*E2-(E2-E_e)*E1
    den = E_e*(E2-E1)
    return math.acos(num/den)
  elif E_e < E1:
    return math.pi
  else:
   return None

def A_HE(E_e):
  if E_e >= E1 and E_e <= E2:
   return   (a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi)
  elif E_e < E1:
    return a
  else:
   return None
def B_HE(E_e):
   if E_e >= E1 and E_e <= E2:
    return   a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)
   elif E_e < E1:
    return a**2 + (b1**2)/2
   else:
    return None

#Check if values are working
print("The value of E1 is:", E1)
print("The value of E2 is:", E2)



# Define functions for vortex unpolarized
def vup(E_e):
    if E_e >= E1 and E_e <= E2:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi) - 4*E*E_e*(a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)))
    elif E_e < E1:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a)-2*E*E_e*(2*a**2+b1**2))
    else:
        return None


# Define functions for vortex parallel polarized
def VP(E_e):
    if E_e >= E1 and E_e <= E2:
        return vup(E_e) + (4 *y * (E_e**2) / (math.pi * m**5)) * (m**2 * (t(E_e) /(math.pi * b * y**2) - A_HE(E_e) / b) - 4 * E_e*E* (A_HE(E_e) /(b * y**2) - B_HE(E_e) / b))
    elif E_e < E1:
        return (vup(E_e) + (4 *y * (E_e**2) / (math.pi * m**5)) * (m**2 * (1 /( b * y**2) - A_HE(E_e) / b) - 4 * E_e*E* (A_HE(E_e) /(b * y**2) - B_HE(E_e) / b)))
    else:
        return None

r1= (b*math.cos(theta)-math.cos(theta_0))/y*b*math.sin(theta_0)
r2=math.cos(theta_0)/y*b*math.sin(theta_0)

# Define functions for vortex radial polarized
def RP(E_e):
    if E_e >= E1 and E_e <= E2:
        return  (vup(E_e)+(4*y*(E_e**2)/(math.pi*m**5))*(m**2*(r1*t(E_e)/math.pi+r2*A_HE(E_e))-4*E*E_e*(r1*A_HE(E_e)+r2*B_HE(E_e))))
    elif E_e < E1:
        return (vup(E_e)+(4*y*(E_e**2)/(math.pi*m**5))*(m**2*(r1+r2*A_HE(E_e))-4*E*E_e*(r1*A_HE(E_e)+r2*B_HE(E_e))))
    else:
        return None


# Define functions for planewave unpolarized
def PWun(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2))
  else:
       return None

# Define functions for planewave forward-polarized
def PWP(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2-(beta-np.cos(theta))*(m**2-4*E*E_e*(1-b*math.cos(theta)))))
  else:
       return None

# Define a range of values for E_e
E_e_values = [i/10000 for i in range(1, 12000)]

# Calculate the corresponding values of w and vortex for each E_e value
vup_values = [vup(E_e) for E_e in E_e_values]
vp_values = [VP(E_e) for E_e in E_e_values]
pwun_values = [PWun(E_e) for E_e in E_e_values]
pwp_values = [PWP(E_e) for E_e in E_e_values]
rp_values = [RP(E_e) for E_e in E_e_values]
# Create a plot of w vs E_e and vortex vs E_e
fig, ax = plt.subplots()
ax.plot(E_e_values, vup_values, color='red',linestyle='dotted', label='Vortex unpolarized')
ax.plot(E_e_values, vp_values, color='red',linestyle='solid', label='Vortex parallel')
ax.plot(E_e_values, rp_values, color='red',linestyle='dashed', label='Vortex radial')
ax.plot(E_e_values, pwun_values, color='black',linestyle='dotted', label='PW unpoalrized')
ax.plot(E_e_values, pwp_values, color='black',linestyle='solid', label='PW polarized')
ax.set_xlabel('$E_4$ GeV)')
ax.set_ylabel('$w(θ,E_4)$ (GeV$^{-1}$)')

plt.text(0.6, 65, r'$\theta_0 =$' + str(theta_0), fontsize=12)
# Add minor ticks to the x-axis
ax.minorticks_on()
ax.tick_params(which='minor', axis='y', color='k', width=0.5, length=0.5)
plt.legend()
plt.show()
# Out:
# The value of Em is: 0.9223159862084832
# The value of E1 is: 0.7130499816002681
# The value of E2 is: 1.2173502241996093

# %%
import math
import matplotlib.pyplot as plt
import numpy as np


# Define the given parameters
E = 3.1
m = 0.1056583755
y = 29.3
theta = math.pi/60
b = math.sqrt(y**2 - 1)/y
theta_0 = 0.1
Em= m**2/(2*E*(1-b*math.cos(theta)))
print("The value of Em is:", Em)

E1= m**2/(2*E*(1-b*math.cos(theta+theta_0)))

E2=m**2/(2*E*(1-b*math.cos(theta-theta_0)))

# Define constants a and b1
a = 1-b*math.cos(theta)*math.cos(theta_0)
b1 = b*math.sin(theta)*math.sin(theta_0)

A_LE = a
B_LE = a**2 + (b1**2)/2
beta = b
gamma = y


def t(E_e):
    num = (E_e-E1)*E2-(E2-E_e)*E1
    den = E_e*(E2-E1)
    return math.acos(num/den)

def A_HE(E_e):
  return   (a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi)

def B_HE(E_e):
  return  a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)

#Check if values are working
print("The value of E1 is:", E1)
print("The value of E2 is:", E2)



# Define functions for vortex unpolarized
def vup(E_e):
    if E_e >= E1 and E_e <= E2:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi) - 4*E*E_e*(a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)))
    elif E_e < E1:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a)-2*E*E_e*(2*a**2+b1**2))
    else:
        return None


# Define functions for vortex parallel polarized
def VP(E_e):
    if E_e >= E1 and E_e <= E2:
        return (vup(E_e)-(4*y*(E_e**2)/(math.pi*m**5))*(m/E)*((y*(m**2*(a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi) - 4*E*E_e*(a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)))/beta) - ((m**2*t(E_e)/np.pi - 4*E*E_e*(a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi))/(beta*y))) )
    elif E_e < E1:
        return (vup(E_e)-(4*y*(E_e**2)/(math.pi*m**5))*(m/E)*((y*(m**2*a - 2*E*E_e*(2*a**2+b1**2))/beta) - ((m**2 - 4*E*E_e*a)/(beta*y))))
    else:
        return None

# Define functions for vortex radial polarized
def RP(E_e):
    if E_e >= E1 and E_e <= E2:
        return  (vup(E_e)-(4*y*(E_e**2)/(math.pi*m**5))*(m/E)*((np.cos(theta_0)-beta*np.cos(theta))*(m**2*t(E_e)/math.pi-4*E*E_e*A_HE(E_e))/(beta*np.sin(theta_0))-np.cos(theta_0)*(m**2*A_HE(E_e)-4*E_e*E*B_HE(E_e))/(beta*np.sin(theta_0))))
    elif E_e < E1:
        return (vup(E_e)-(4*y*(E_e**2)/(math.pi*m**5))*(m/E)*((np.cos(theta_0)-beta*np.cos(theta))*(m**2-4*E*E_e*a)/(beta*np.sin(theta_0))-np.cos(theta_0)*(m**2*a-4*E_e*E*(a**2 + (b1**2)/2))/(beta*np.sin(theta_0))))
    else:
        return None


# Define functions for planewave unpolarized
def PWun(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2))
  else:
       return None

# Define functions for planewave forward-polarized
def PWP(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2-(beta-np.cos(theta))*(m**2-4*E*E_e*(1-b*math.cos(theta)))))
  else:
       return None

# Define a range of values for E_e
E_e_values = [i/10000 for i in range(1, 8000)]

# Calculate the corresponding values of w and vortex for each E_e value
vup_values = [vup(E_e) for E_e in E_e_values]
vp_values = [VP(E_e) for E_e in E_e_values]
pwun_values = [PWun(E_e) for E_e in E_e_values]
pwp_values = [PWP(E_e) for E_e in E_e_values]
rp_values = [RP(E_e) for E_e in E_e_values]
# Create a plot of w vs E_e and vortex vs E_e
fig, ax = plt.subplots()
ax.plot(E_e_values, vup_values, color='red',linestyle='dotted', label='Vortex unpolarized')
ax.plot(E_e_values, vp_values, color='red',linestyle='solid', label='Vortex parallel')
ax.plot(E_e_values, rp_values, color='red',linestyle='dashed', label='Vortex radial')
ax.plot(E_e_values, pwun_values, color='black',linestyle='dotted', label='PW unpoalrized')
ax.plot(E_e_values, pwp_values, color='black',linestyle='solid', label='PW polarized')
ax.set_xlabel('$E_4$ GeV')
ax.set_ylabel('$w(θ,E_4)$ (GeV$^{-1})$')

plt.text(0.4, 60, r'$\theta_0 =$' + str(theta_0), fontsize=12)
# Add minor ticks to the x-axis
ax.minorticks_on()
ax.tick_params(which='minor', axis='y', color='k', width=0.5, length=0.5)
plt.legend()
plt.show()
# Out:
# The value of Em is: 0.9223159862084832
# The value of E1 is: 0.14807322716570637
# The value of E2 is: 1.0489907934354714

# %%
import math
import matplotlib.pyplot as plt
import numpy as np


# Define the given parameters
E = 3.1
m = 0.1056583755
y = E/m
theta = math.pi/60
b = math.sqrt(y**2 - 1)/y
theta_0 = 0.01
Em= m**2/(2*E*(1-b*math.cos(theta)))
print("The value of Em is:", Em)

E1= m**2/(2*E*(1-b*math.cos(theta+theta_0)))

E2=m**2/(2*E*(1-b*math.cos(theta-theta_0)))

# Define constants a and b1
a = 1-b*math.cos(theta)*math.cos(theta_0)
b1 = b*math.sin(theta)*math.sin(theta_0)

A_LE = a
B_LE = a**2 + (b1**2)/2
beta = b
gamma = y


def t(E_e):
  if E_e >= E1 and E_e <= E2:
    num = (E_e-E1)*E2-(E2-E_e)*E1
    den = E_e*(E2-E1)
    return math.acos(num/den)
  elif E_e < E1:
    return math.pi
  else:
   return None

def A_HE(E_e):
  if E_e >= E1 and E_e <= E2:
   return   (a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi)
  elif E_e < E1:
    return a
  else:
   return None
def B_HE(E_e):
   if E_e >= E1 and E_e <= E2:
    return   a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)
   elif E_e < E1:
    return a**2 + (b1**2)/2
   else:
    return None

def test(E_e):
   return (4*y*(E_e**2)/(math.pi*m**5))*(m**2*(r1*t(E_e)/math.pi+r2*A_HE(E_e))-4*E*E_e*(r1*A_HE(E_e)+r2*B_HE(E_e)))
#Check if values are working
print("The value of E1 is:", E1)
print("The value of E2 is:", E2)
print("the value of t at E1 is", t(E1))
print("the value of test at E1 is", test(E1))

# Define functions for vortex unpolarized
def vup(E_e):
    if E_e >= E1 and E_e <= E2:
        return (4*y*(E_e**2)/(math.pi*m**5))*((3*m**2*A_HE(E_e)) - 4*E*E_e*(B_HE(E_e)))
    elif E_e < E1:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(A_HE(E_e))-4*E*E_e*(B_HE(E_e)))
    else:
        return None

# Define functions for vortex parallel polarized
def VP(E_e):
    if E_e >= E1 and E_e <= E2:
        return (4 *y * (E_e**2) / (math.pi * m**5)) * (m**2 * (3*A_HE(E_e)+t(E_e) /(math.pi * b * y**2) - A_HE(E_e) / b) - 4 * E_e*E* (B_HE(E_e)+A_HE(E_e) /(b * y**2) - B_HE(E_e) / b))
    elif E_e < E1:
        return ((4 *y * (E_e**2) / (math.pi * m**5)) * (m**2 * (3*A_HE(E_e)+1 /( b * y**2) - A_HE(E_e) / b) - 4 * E_e*E* (B_HE(E_e)+A_HE(E_e) /(b * y**2) - B_HE(E_e) / b)))
    else:
        return None

r1= (b*math.cos(theta)-math.cos(theta_0))/y*b*math.sin(theta_0)
r2=math.cos(theta_0)/y*b*math.sin(theta_0)
print("The value of Er1 is:", r1)
print("The value of r2 is:", r2)
# Define functions for vortex radial polarized
def RP(E_e):
    if E_e >= E1 and E_e <= E2:
        return  ((4*y*(E_e**2)/(math.pi*m**5))*(m**2*(3*A_HE(E_e)-r1*t(E_e)/math.pi-r2*A_HE(E_e))-4*E*E_e*(B_HE(E_e)-r1*A_HE(E_e)-r2*B_HE(E_e))))
    elif E_e < E1:
        return ((4*y*(E_e**2)/(math.pi*m**5))*(m**2*(3*A_HE(E_e)-r1*t(E_e)/math.pi-r2*A_HE(E_e))-4*E*E_e*(B_HE(E_e)-r1*A_HE(E_e)-r2*B_HE(E_e))))
    else:
        return None


# Define functions for planewave unpolarized
def PWun(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2))
  else:
       return None

# Define functions for planewave forward-polarized
def PWP(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2-(beta-np.cos(theta))*(m**2-4*E*E_e*(1-b*math.cos(theta)))))
  else:
       return None

# Define a range of values for E_e
E_e_values = [i/10000 for i in range(1, 12000)]

# Calculate the corresponding values of w and vortex for each E_e value
vup_values = [vup(E_e) for E_e in E_e_values]
vp_values = [VP(E_e) for E_e in E_e_values]
pwun_values = [PWun(E_e) for E_e in E_e_values]
pwp_values = [PWP(E_e) for E_e in E_e_values]
rp_values = [RP(E_e) for E_e in E_e_values]
# Create a plot of w vs E_e and vortex vs E_e
fig, ax = plt.subplots()
ax.plot(E_e_values, vup_values, color='red',linestyle='dotted', label='Vortex unpolarized')
ax.plot(E_e_values, vp_values, color='red',linestyle='solid', label='Vortex parallel')
ax.plot(E_e_values, rp_values, color='red',linestyle='dashed', label='Vortex radial')
ax.plot(E_e_values, pwun_values, color='black',linestyle='dotted', label='PW unpoalrized')
ax.plot(E_e_values, pwp_values, color='black',linestyle='solid', label='PW polarized')
ax.set_xlabel('$E_4$ GeV')
ax.set_ylabel('$w(θ,E_4)$ (GeV$^{-1})$')

plt.text(0.4, 60, r'$\theta_0 =$' + str(theta_0), fontsize=12)
# Add minor ticks to the x-axis
ax.minorticks_on()
ax.tick_params(which='minor', axis='y', color='k', width=0.5, length=0.5)
plt.legend()
plt.show()
# Out:
# The value of Em is: 0.9230627799341063
# The value of E1 is: 0.713495999012278
# The value of E2 is: 1.2186521637663665
# the value of t at E1 is 3.141592653589793
# the value of test at E1 is 0.034243528839799815
# The value of Er1 is: -6.474266391050672e-07
# The value of r2 is: 0.0003406127344706573

# %%
import math
import matplotlib.pyplot as plt
import numpy as np


# Define the given parameters
E = 3.1
m = 0.1056583755
y = 29.3
theta = math.pi/60
b = math.sqrt(y**2 - 1)/y
theta_0 = 0.01
Em= m**2/(2*E*(1-b*math.cos(theta)))
print("The value of Em is:", Em)

E1= m**2/(2*E*(1-b*math.cos(theta+theta_0)))

E2=m**2/(2*E*(1-b*math.cos(theta-theta_0)))

# Define constants a and b1
a = 1-b*math.cos(theta)*math.cos(theta_0)
b1 = b*math.sin(theta)*math.sin(theta_0)

A_LE = a
B_LE = a**2 + (b1**2)/2
beta = b
gamma = y


def t(E_e):
    num = (E_e-E1)*E2-(E2-E_e)*E1
    den = E_e*(E2-E1)
    return math.acos(num/den)

def A_HE(E_e):
  return   (a*t(E_e)/math.pi - b1*math.sin(t(E_e))/math.pi)

def B_HE(E_e):
  return  a**2*t(E_e)/math.pi + b1**2*t(E_e)/(2*math.pi) - 2*a*b1*math.sin(t(E_e))/math.pi + b1**2*math.sin(2*t(E_e))/(4*math.pi)

def test(E_e):
   return (m**2 * (t(E_e) /(math.pi * b * y**2) - A_HE(E_e) / b) - 4 * E_e*E* (A_HE(E_e) /(b * y**2) - B_HE(E_e) / b))- (m**2 * ((1 /(b * y**2) - a / b) - 4 * E_e*E* (a /(b * y**2) - (2*a**2+b1**2) /b)))

#Check if values are working
print("The value of E1 is:", E1)
print("The value of E2 is:", E2)
print("the value of t at E1 is", t(E1))
print("the value of test at E1 is", test(E1))

# Define functions for vortex unpolarized
def vup(E_e):
    if E_e >= E1 and E_e <= E2:
        return (4*y*(E_e**2)/(math.pi*m**5))*((3*m**2*A_HE(E_e)) - 4*E*E_e*(B_HE(E_e)))
    elif E_e < E1:
        return (4*y*(E_e**2)/(math.pi*m**5))*(3*m**2*(a)-2*E*E_e*(2*a**2+b1**2))
    else:
        return None


# Define functions for vortex parallel polarized
def VP(E_e):
    if E_e >= E1 and E_e <= E2:
        return vup(E_e) + (4 *y * (E_e**2) / (math.pi * m**5)) * (m**2 * (t(E_e) /(math.pi * b * y**2) - A_HE(E_e) / b) - 4 * E_e*E* (A_HE(E_e) /(b * y**2) - B_HE(E_e) / b))
    elif E_e < E1:
        return (vup(E_e) - (4 * y * (E_e**2) / (math.pi * m**5)) * (m**2 * ((1 /(b * y**2) - a / b) - 4 * E_e*E* (a /(b * y**2) - (2*a**2+b1**2) /b))))
    else:
        return None

# Define functions for vortex radial polarized
def RP(E_e):
    if E_e >= E1 and E_e <= E2:
        return  (vup(E_e)-(4*y*(E_e**2)/(math.pi*m**5))*(m/E)*((np.cos(theta_0)-beta*np.cos(theta))*(m**2*t(E_e)/math.pi-4*E*E_e*A_HE(E_e))/(beta*np.sin(theta_0))-np.cos(theta_0)*(m**2*A_HE(E_e)-4*E_e*E*B_HE(E_e))/(beta*np.sin(theta_0))))
    elif E_e < E1:
        return (vup(E_e)-(4*y*(E_e**2)/(math.pi*m**5))*(m/E)*((np.cos(theta_0)-beta*np.cos(theta))*(m**2-4*E*E_e*a)/(beta*np.sin(theta_0))-np.cos(theta_0)*(m**2*a-4*E_e*E*(a**2 + (b1**2)/2))/(beta*np.sin(theta_0))))
    else:
        return None


# Define functions for planewave unpolarized
def PWun(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2))
  else:
       return None

# Define functions for planewave forward-polarized
def PWP(E_e):
  if E_e< Em:
       return (4*y*(E_e**2)/(math.pi*m**5)*(3*m**2*(1-b*math.cos(theta))-4*E*E_e*(1-b*math.cos(theta))**2-(beta-np.cos(theta))*(m**2-4*E*E_e*(1-b*math.cos(theta)))))
  else:
       return None

# Define a range of values for E_e
E_e_values = [i/10000 for i in range(1, 12000)]

# Calculate the corresponding values of w and vortex for each E_e value
vup_values = [vup(E_e) for E_e in E_e_values]
vp_values = [VP(E_e) for E_e in E_e_values]
pwun_values = [PWun(E_e) for E_e in E_e_values]
pwp_values = [PWP(E_e) for E_e in E_e_values]
rp_values = [RP(E_e) for E_e in E_e_values]
# Create a plot of w vs E_e and vortex vs E_e
fig, ax = plt.subplots()
ax.plot(E_e_values, vup_values, color='red',linestyle='dotted', label='Vortex unpolarized')
ax.plot(E_e_values, vp_values, color='red',linestyle='solid', label='Vortex parallel')
ax.plot(E_e_values, rp_values, color='red',linestyle='dashed', label='Vortex radial')
ax.plot(E_e_values, pwun_values, color='black',linestyle='dotted', label='PW unpoalrized')
ax.plot(E_e_values, pwp_values, color='black',linestyle='solid', label='PW polarized')
ax.set_xlabel('$E_4$ GeV')
ax.set_ylabel('$w(θ,E_4)$ (GeV$^{-1})$')

plt.text(0.4, 60, r'$\theta_0 =$' + str(theta_0), fontsize=12)
# Add minor ticks to the x-axis
ax.minorticks_on()
ax.tick_params(which='minor', axis='y', color='k', width=0.5, length=0.5)
plt.legend()
plt.show()
# Out:
# The value of Em is: 0.9223159862084832
# The value of E1 is: 0.7130499816002681
# The value of E2 is: 1.2173502241996093
# the value of t at E1 is 3.141592653589793
# the value of test at E1 is 1.5453139200798836e-05
